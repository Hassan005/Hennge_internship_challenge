# %%
output=[]
def result(data):
    count=0
    test=True
    while count<len(data):
        output=data[count]
        print(output)
        count+=1
def check_Yn_conditon_limit(Yn):
    check=True
    count=0;
    test=True
    while test:
        if count>=len(Yn):
            test=False
        else:
            if Yn[count] >=-100 and Yn[count] <=100:
                check=True
            else:
                check=False
                break
            count+=1
    return check

N=int(input())
if N>=1 and N<=100:
    
    while N>0:
        check =True
        count=0
        sums=0
        X=int(input())
        if X>=0 and X<=100:
            Yn =list(map(int,input().split()))
            condition=check_Yn_conditon_limit(Yn)
            if condition==False:
                print("Value out of range")
                break
            else:
                if X==len(Yn):
                    while check:
                        if Yn[count]<0:
                            count+=1
                            continue
                        else:   
                            square=Yn[count]*Yn[count]
                            count+=1
                            sums=sums+square
                        if count>=len(Yn):
                            check=False
#                 print(sums)
                N-=1
                
        else:
            print("Value should be between 0 and 100")
            break
        output.append(sums)     
else:
    print("Value should be between 1 and 100")

result(output)
